# %%
# Importação de bibliotecas externas necessárias
import sys
import os
import cProfile as cpr
from pyprof2calltree import convert

sys.path.append(os.path.abspath("../..")) 


import logging
from Modules.Models import * 
from Modules.Methods import *
from Modules.Handlers import *
from datetime import datetime



string_data = datetime.now().strftime("%d_%m_%Y_%H_%M")

# %%
#gens=[25,50,100,200,400,800,1600,3200]
gens=[200]
handlers=[]
for gen in gens:
    handler = ExecutionHandler(
        model=ModelWrapper.GRN5(train_percentage=0.7),              #"configures" the "model-object", to be ready to use
        method_class=DE,
        seeds=[0],
        solvers=['ODEINT'],
        errors=['MSE'],
        generations=gen,
        parallel=False,
    )
    handlers.append(handler)

handler
# Out:
# <ExecutionHandler Configuration>
# { 'Additional Params': {},
#   'Errors': ['MSE'],
#   'Generations': 200,
#   'Method Name': 'DE',
#   'Model Name': 'GRN5',
#   'Output Directory': '../../Outputs/',
#   'Parallel Execution': False,
#   'Seeds': [0],
#   'Solvers': ['ODEINT'],
#   'train_percentage': 0.7}

# %%
if __name__ == "__main__":    #garantees that the code will be profilled when ran, not imported
    with cpr.Profile() as profile: #runs everything inside the block using the Profile()
        for handler in handlers:
            handler.execute()

callgrind_filename = f"callgrind.{string_data}_GRN5_DE_Parallel_{gen}_generations_results.out"
convert(profile.getstats(), callgrind_filename)
print(f"Profiling complete! Open QCacheGrind and load: {callgrind_filename}")
# Out:
# Starting execution with ID: GRN5_DE_SERIAL_20260831_045025
# Running with seed=0, solver=ODEINT, error=MSE
# setando seed: 0
# c:\Users\Pedro\faculdade\IniciacaoCientifica\rep\Bolsa-GRN-Performance\.grn\Lib\site-packages\scipy\integrate\_ivp\ivp.py:623: UserWarning: The following arguments have no effect for a chosen solver: `min_step`.
#   solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
# differential_evolution step 1: f(x)= 3.97534932112009
# differential_evolution step 2: f(x)= 3.97534932112009
# differential_evolution step 3: f(x)= 3.97534932112009
# differential_evolution step 4: f(x)= 3.97534932112009
# differential_evolution step 5: f(x)= 3.97534932112009
# differential_evolution step 6: f(x)= 3.97534932112009
# differential_evolution step 7: f(x)= 3.97534932112009
# differential_evolution step 8: f(x)= 3.97534932112009
# differential_evolution step 9: f(x)= 3.97534932112009
# differential_evolution step 10: f(x)= 3.97534932112009
# differential_evolution step 11: f(x)= 3.6591932030328906
# differential_evolution step 12: f(x)= 3.6591932030328906
# differential_evolution step 13: f(x)= 3.6591932030328906
# differential_evolution step 14: f(x)= 3.6591932030328906
# differential_evolution step 15: f(x)= 3.6591932030328906
# differential_evolution step 16: f(x)= 3.6591932030328906
# differential_evolution step 17: f(x)= 3.6591932030328906
# differential_evolution step 18: f(x)= 3.6591932030328906
# differential_evolution step 19: f(x)= 3.6591932030328906
# differential_evolution step 20: f(x)= 3.6591932030328906
# differential_evolution step 21: f(x)= 3.6591932030328906
# differential_evolution step 22: f(x)= 3.6591932030328906
# differential_evolution step 23: f(x)= 3.383478111343588
# differential_evolution step 24: f(x)= 3.145614170959358
# differential_evolution step 25: f(x)= 3.145614170959358
# differential_evolution step 26: f(x)= 3.145614170959358
# differential_evolution step 27: f(x)= 3.0460371002472035
# differential_evolution step 28: f(x)= 3.0460371002472035
# differential_evolution step 29: f(x)= 3.0460371002472035
# differential_evolution step 30: f(x)= 2.808563572799943
# differential_evolution step 31: f(x)= 2.808563572799943
# differential_evolution step 32: f(x)= 2.808563572799943
# differential_evolution step 33: f(x)= 2.808563572799943
# differential_evolution step 34: f(x)= 2.808563572799943
# differential_evolution step 35: f(x)= 2.5554550592104235
# differential_evolution step 36: f(x)= 2.5554550592104235
# differential_evolution step 37: f(x)= 2.5554550592104235
# differential_evolution step 38: f(x)= 2.5554550592104235
# differential_evolution step 39: f(x)= 2.5554550592104235
# differential_evolution step 40: f(x)= 2.5554550592104235
# differential_evolution step 41: f(x)= 2.5554550592104235
# differential_evolution step 42: f(x)= 2.5554550592104235
# differential_evolution step 43: f(x)= 2.5554550592104235
# differential_evolution step 44: f(x)= 2.5554550592104235
# differential_evolution step 45: f(x)= 2.5554550592104235
# differential_evolution step 46: f(x)= 2.5554550592104235
# differential_evolution step 47: f(x)= 2.5554550592104235
# differential_evolution step 48: f(x)= 2.5554550592104235
# differential_evolution step 49: f(x)= 2.5554550592104235
# differential_evolution step 50: f(x)= 2.5554550592104235
# differential_evolution step 51: f(x)= 2.476222726759108
# differential_evolution step 52: f(x)= 2.476222726759108
# differential_evolution step 53: f(x)= 2.476222726759108
# differential_evolution step 54: f(x)= 2.476222726759108
# differential_evolution step 55: f(x)= 2.476222726759108
# differential_evolution step 56: f(x)= 2.476222726759108
# differential_evolution step 57: f(x)= 2.476222726759108
# differential_evolution step 58: f(x)= 2.476222726759108
# differential_evolution step 59: f(x)= 2.476222726759108
# differential_evolution step 60: f(x)= 2.476222726759108
# differential_evolution step 61: f(x)= 2.476222726759108
# differential_evolution step 62: f(x)= 2.476222726759108
# differential_evolution step 63: f(x)= 2.476222726759108
# differential_evolution step 64: f(x)= 2.476222726759108
# differential_evolution step 65: f(x)= 2.476222726759108
# differential_evolution step 66: f(x)= 2.476222726759108
# differential_evolution step 67: f(x)= 2.476222726759108
# differential_evolution step 68: f(x)= 2.476222726759108
# differential_evolution step 69: f(x)= 2.399981594012242
# differential_evolution step 70: f(x)= 2.399981594012242
# differential_evolution step 71: f(x)= 2.399981594012242
# differential_evolution step 72: f(x)= 2.399981594012242
# differential_evolution step 73: f(x)= 2.399981594012242
# differential_evolution step 74: f(x)= 2.399981594012242
# differential_evolution step 75: f(x)= 2.399981594012242
# differential_evolution step 76: f(x)= 2.399981594012242
# differential_evolution step 77: f(x)= 2.399981594012242
# differential_evolution step 78: f(x)= 2.399981594012242
# differential_evolution step 79: f(x)= 2.399981594012242
# differential_evolution step 80: f(x)= 2.399981594012242
# differential_evolution step 81: f(x)= 2.399981594012242
# differential_evolution step 82: f(x)= 2.399981594012242
# differential_evolution step 83: f(x)= 2.399981594012242
# differential_evolution step 84: f(x)= 2.399981594012242
# differential_evolution step 85: f(x)= 2.399981594012242
# differential_evolution step 86: f(x)= 2.399981594012242
# differential_evolution step 87: f(x)= 2.399981594012242
# differential_evolution step 88: f(x)= 2.399981594012242
# differential_evolution step 89: f(x)= 2.399981594012242
# differential_evolution step 90: f(x)= 2.399981594012242
# differential_evolution step 91: f(x)= 2.399981594012242
# differential_evolution step 92: f(x)= 2.399981594012242
# differential_evolution step 93: f(x)= 2.399981594012242
# differential_evolution step 94: f(x)= 2.399981594012242
# differential_evolution step 95: f(x)= 2.399981594012242
# differential_evolution step 96: f(x)= 2.399981594012242
# differential_evolution step 97: f(x)= 2.399981594012242
# differential_evolution step 98: f(x)= 2.399981594012242
# differential_evolution step 99: f(x)= 2.268411171224526
# differential_evolution step 100: f(x)= 2.268411171224526
# differential_evolution step 101: f(x)= 2.268411171224526
# differential_evolution step 102: f(x)= 2.268411171224526
# differential_evolution step 103: f(x)= 2.268411171224526
# differential_evolution step 104: f(x)= 2.268411171224526
# differential_evolution step 105: f(x)= 2.268411171224526
# differential_evolution step 106: f(x)= 2.268411171224526
# differential_evolution step 107: f(x)= 2.268411171224526
# differential_evolution step 108: f(x)= 2.268411171224526
# differential_evolution step 109: f(x)= 2.268411171224526
# differential_evolution step 110: f(x)= 2.268411171224526
# differential_evolution step 111: f(x)= 2.268411171224526
# differential_evolution step 112: f(x)= 2.268411171224526
# differential_evolution step 113: f(x)= 2.268411171224526
# differential_evolution step 114: f(x)= 2.268411171224526
# differential_evolution step 115: f(x)= 2.268411171224526
# differential_evolution step 116: f(x)= 2.268411171224526
# differential_evolution step 117: f(x)= 2.238222021796681
# differential_evolution step 118: f(x)= 2.238222021796681
# differential_evolution step 119: f(x)= 2.238222021796681
# differential_evolution step 120: f(x)= 2.238222021796681
# differential_evolution step 121: f(x)= 2.238222021796681
# differential_evolution step 122: f(x)= 2.238222021796681
# differential_evolution step 123: f(x)= 2.238222021796681
# differential_evolution step 124: f(x)= 2.238222021796681
# differential_evolution step 125: f(x)= 2.238222021796681
# differential_evolution step 126: f(x)= 2.238222021796681
# differential_evolution step 127: f(x)= 2.238222021796681
# differential_evolution step 128: f(x)= 2.238222021796681
# differential_evolution step 129: f(x)= 2.238222021796681
# differential_evolution step 130: f(x)= 2.238222021796681
# differential_evolution step 131: f(x)= 2.238222021796681
# differential_evolution step 132: f(x)= 2.17305605225096
# differential_evolution step 133: f(x)= 2.17305605225096
# differential_evolution step 134: f(x)= 2.0930453810747003
# differential_evolution step 135: f(x)= 2.0930453810747003
# differential_evolution step 136: f(x)= 2.0930453810747003
# differential_evolution step 137: f(x)= 2.0930453810747003
# differential_evolution step 138: f(x)= 2.0930453810747003
# differential_evolution step 139: f(x)= 2.0930453810747003
# differential_evolution step 140: f(x)= 2.0930453810747003
# differential_evolution step 141: f(x)= 2.0930453810747003
# differential_evolution step 142: f(x)= 2.0930453810747003
# differential_evolution step 143: f(x)= 2.0930453810747003
# differential_evolution step 144: f(x)= 2.0930453810747003
# differential_evolution step 145: f(x)= 2.0930453810747003
# differential_evolution step 146: f(x)= 2.0930453810747003
# differential_evolution step 147: f(x)= 2.0930453810747003
# differential_evolution step 148: f(x)= 2.0930453810747003
# differential_evolution step 149: f(x)= 2.0930453810747003
# differential_evolution step 150: f(x)= 2.0930453810747003
# differential_evolution step 151: f(x)= 2.0930453810747003
# differential_evolution step 152: f(x)= 2.0930453810747003
# differential_evolution step 153: f(x)= 2.0930453810747003
# differential_evolution step 154: f(x)= 2.0930453810747003
# differential_evolution step 155: f(x)= 2.0930453810747003
# differential_evolution step 156: f(x)= 2.0930453810747003
# differential_evolution step 157: f(x)= 2.0930453810747003
# differential_evolution step 158: f(x)= 2.0930453810747003
# differential_evolution step 159: f(x)= 2.0930453810747003
# differential_evolution step 160: f(x)= 2.0930453810747003
# differential_evolution step 161: f(x)= 2.0930453810747003
# differential_evolution step 162: f(x)= 2.0930453810747003
# differential_evolution step 163: f(x)= 2.0930453810747003
# differential_evolution step 164: f(x)= 2.0930453810747003
# differential_evolution step 165: f(x)= 2.0930453810747003
# differential_evolution step 166: f(x)= 2.0930453810747003
# differential_evolution step 167: f(x)= 2.0930453810747003
# differential_evolution step 168: f(x)= 2.0797779419692137
# differential_evolution step 169: f(x)= 1.940614191342878
# differential_evolution step 170: f(x)= 1.940614191342878
# differential_evolution step 171: f(x)= 1.940614191342878
# differential_evolution step 172: f(x)= 1.940614191342878
# differential_evolution step 173: f(x)= 1.940614191342878
# differential_evolution step 174: f(x)= 1.940614191342878
# differential_evolution step 175: f(x)= 1.940614191342878
# differential_evolution step 176: f(x)= 1.940614191342878
# differential_evolution step 177: f(x)= 1.940614191342878
# differential_evolution step 178: f(x)= 1.940614191342878
# differential_evolution step 179: f(x)= 1.940614191342878
# differential_evolution step 180: f(x)= 1.940614191342878
# differential_evolution step 181: f(x)= 1.940614191342878
# differential_evolution step 182: f(x)= 1.940614191342878
# differential_evolution step 183: f(x)= 1.940614191342878
# differential_evolution step 184: f(x)= 1.940614191342878
# differential_evolution step 185: f(x)= 1.940614191342878
# differential_evolution step 186: f(x)= 1.940614191342878
# differential_evolution step 187: f(x)= 1.940614191342878
# differential_evolution step 188: f(x)= 1.940614191342878
# differential_evolution step 189: f(x)= 1.940614191342878
# differential_evolution step 190: f(x)= 1.940614191342878
# differential_evolution step 191: f(x)= 1.940614191342878
# differential_evolution step 192: f(x)= 1.940614191342878
# differential_evolution step 193: f(x)= 1.940614191342878
# differential_evolution step 194: f(x)= 1.940614191342878
# differential_evolution step 195: f(x)= 1.940614191342878
# differential_evolution step 196: f(x)= 1.940614191342878
# differential_evolution step 197: f(x)= 1.940614191342878
# differential_evolution step 198: f(x)= 1.940614191342878
# differential_evolution step 199: f(x)= 1.940614191342878
# differential_evolution step 200: f(x)= 1.940614191342878
# Polishing solution with 'L-BFGS-B'
# calculando fitness baseado no teste
# teste:  [51.4286 52.898  54.3673 55.8367 57.3061 58.7755 60.2449 61.7143 63.1837
#  64.6531 66.1224 67.5918 69.0612 70.5306 72.    ] [ 0.      1.4694  2.9388  4.4082  5.8776  7.3469  8.8163 10.2857 11.7551
#  13.2245 14.6939 16.1633 17.6327 19.102  20.5714 22.0408 23.5102 24.9796
#  26.449  27.9184 29.3878 30.8571 32.3265 33.7959 35.2653 36.7347 38.2041
#  39.6735 41.1429 42.6122 44.0816 45.551  47.0204 48.4898 49.9592]
#                                             best_ind error_type  solver  seed  \
# 0  Individual(fitness=inf, coeffs={'A': {'E': {'n...        MSE  ODEINT     0
#
#    ABS_Fitness  SQUARED_Fitness  MSE_Fitness  MABS_Fitness  execution_time  \
# 0    19.116524          3.19126     0.135789      0.254887      352.821033
#
#   model method  parallel                          run_id
# 0  GRN5     DE     False  GRN5_DE_SERIAL_20260831_045025
# Profiling complete! Open QCacheGrind and load: callgrind.31_08_2026_04_50_GRN5_DE_Parallel_200_generations_results.out
